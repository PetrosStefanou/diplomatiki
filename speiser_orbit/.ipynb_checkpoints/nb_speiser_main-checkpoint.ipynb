# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy.signal import find_peaks
import numpy as np
import time

from pulsars import Pulsars, c, e_charge, e_mass
import speiser_fun as sf 
import speiser_integ 
import speiser_plots as sp

# %%
k = 10**3
pulsar = Pulsars(k)

B_0 = pulsar['crab']['Blc']
gamma1 = 10**0
omegaB = (e_charge*B_0/(gamma1*e_mass*c))    #γυροσυχνότητα
Delta = pulsar['crab']['rlc']/k*omegaB/c

gamma0 = np.array([10**3., 1.])    #αρχικός παράγοντας Lorentz
delta = 4000./gamma1    #πάχος του φύλλου ρεύματος, αδιάστατο, σε μονάδες [c/ωΒ]

# %%
start_time = time.time()

#ολοκλήρωση
x, ux, y, uy, z, uz, x1, ux1, y1, uy1, z1, uz1 = speiser_integ.oloklirosi(gamma0, Delta, delta, B_0, gamma1, Dt = 10**6, t_end=450.)
# x, ux, y, uy, z, uz, 

#λήξη χρονομέτρησης
elapsed = time.time() - start_time

print('total runtime = {:1.2E} s'.format(elapsed))
# Out:
# total runtime = 4.21E+01 s

# %%
#γραφικές παραστάσεις
sp.plot_zy(x, y, z, ux, uy, uz, x1, y1, z1, ux1, uy1, uz1, omegaB, delta, Delta, gamma0)

sp.plot_zx(x, y, z, ux, uy, uz, x1, y1, z1, ux1, uy1, uz1, omegaB, delta, Delta, gamma0)

sp.plot_zyx(x, y, z, ux, uy, uz, x1, y1, z1, ux1, uy1, uz1, omegaB, delta, Delta, gamma0)

sp.plot_gamma(x, y, z, ux, uy, uz, x1, y1, z1, ux1, uy1, uz1, omegaB, delta, Delta, gamma0, save = 0)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
a = 0.38**(1/4)*0.033**(-1/4)*4*10**7
print('{:1.2E}'.format(a))
# Out:
# 7.37E+07

# %%
b = 0.38*0.033**(-2)*10**8/k
print('{:1.2E}'.format(b))
# Out:
# 3.49E+07

# %%
g = pulsar['crab']['Blc']*e_charge* pulsar['crab']['rlc']/k/(e_mass*c**2)
print('{:1.2E}'.format(g))
# Out:
# 1.48E+08

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
plt.plot(z[0]*c/omegaB, uz[0]**(1/5)/sf.gamma(ux[0], uy[0], uz[0]))
plt.axvline(x = Delta*c/omegaB, linestyle = ':', color = 'r')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
